# %% [markdown]
# # Phase 2: Query Complexity Classifier Training
#
# Use this notebook as the Colab entrypoint for four-class DistilBERT classifier fine-tuning. Export trained artifacts to `data/artifacts/query_classifier_distilbert_v2/` and keep the runtime model wrapper compatible with `QueryClassifier.predict`.

# %%
# Use a fresh Python 3.11 GPU runtime. The project preserves Colab's compatible Torch 2.x build.
# !python -m pip install --upgrade pip setuptools wheel
# !python -m pip install -e ".[ml]"

# %%
# !python scripts/download_wixqa.py --subset all
# !python scripts/generate_synthetic_qac.py --limit 2400
# !python scripts/prepare_four_class_dataset.py
# !python scripts/train_hf_query_classifier.py --dataset data/processed/four_class_qac.jsonl
