# %% [markdown]
# # Phase 2: Query Complexity Classifier Training
#
# Use this notebook as the Colab entrypoint for T5/DistilBERT-style classifier fine-tuning. Export trained artifacts to `data/artifacts/` and keep the runtime model wrapper compatible with `QueryClassifier.predict`.
