# %% [markdown]
# # Phase 2: Query Complexity Classifier Training
#
# Use this notebook as the Colab entrypoint for DistilBERT classifier fine-tuning. Export trained artifacts to `data/artifacts/query_classifier_distilbert/` and keep the runtime model wrapper compatible with `QueryClassifier.predict`.

# %%
# !pip install -e ".[ml]"

# %%
# !python scripts/generate_synthetic_qac.py --limit 90
# !python scripts/train_hf_query_classifier.py --extra-dataset data/processed/wixqa_synthetic_bootstrap_qac.jsonl
